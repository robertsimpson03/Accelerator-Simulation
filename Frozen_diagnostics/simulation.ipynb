# %%
import sys
from pathlib import Path

parent_folder = Path.cwd().parent
if str(parent_folder) not in sys.path:
    sys.path.append(str(parent_folder))
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
from simulation import Simulation

# %% [markdown]
# # Default params with no SC, Direct and Indirect

# %%
beta_gamma = 0.3934 

"""sim = Simulation(threads=10, folder=Path('../Lattice_Files/02_Aperture_Lattice/'))
sim.build_particles(n_particles=5000, 
                    nemitt_x_0=beta_gamma*60e-6, 
                    nemitt_y_0=beta_gamma*60e-6,
                    offset_x=0.001, offset_y=0.001)
sim.set_up(n_turns = 200, n_monitors = 10)
sim.add_spacecharge(beam_intensity=0, n_interactions=50, 
                    indirect_spacecharge=False)
sim.run()
sim.save('data/default/no_sc_pert')"""

sim = Simulation(threads=10, folder=Path('../Lattice_Files/02_Aperture_Lattice/'))
sim.build_particles(n_particles=5000, 
                    nemitt_x_0=beta_gamma*60e-6, 
                    nemitt_y_0=beta_gamma*60e-6,
                    offset_x=0.02, offset_y=0.02)
sim.set_up(n_turns = 200, n_monitors = 10)
sim.add_spacecharge(beam_intensity=5e13, n_interactions=50, 
                    indirect_spacecharge=False)
sim.run()
sim.save('data/default/dir_sc_pert_bigger')

"""sim = Simulation(threads=10, folder=Path('../Lattice_Files/02_Aperture_Lattice/'))
sim.build_particles(n_particles=5000, 
                    nemitt_x_0=beta_gamma*60e-6, 
                    nemitt_y_0=beta_gamma*60e-6,
                    offset_x=0.001, offset_y=0.001)
sim.set_up(n_turns = 50, n_monitors = 50)
sim.add_spacecharge(beam_intensity=5e13, n_interactions=50, 
                    indirect_spacecharge=True)
sim.run()
sim.save('data/default/ind_sc_pert')"""
# Out:
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# File saved at data/default/dir_sc_pert_bigger
# ...
