# %%
from scripts.simulation_apertures import Simulation

# %%
sim = Simulation(n_macro_particles=int(1e4), threads=10)
# Out:
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.

# %%
sim.add_space_charge(beam_intensity=5e11, n_interactions=100)
# Out:
# ...
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]

# %%
sim.run(30)
# Out:
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Turn: 0
# Turn: 1
# Turn: 2
# Turn: 3
# Turn: 4
# Turn: 5
# Turn: 6
# Turn: 7
# Turn: 8
# Turn: 9
# Turn: 10
# Turn: 11
# Turn: 12
# Turn: 13
# Turn: 14
# Turn: 15
# Turn: 16
# Turn: 17
# Turn: 18
# Turn: 19
# Turn: 20
# Turn: 21
# Turn: 22
# Turn: 23
# Turn: 24
# Turn: 25
# Turn: 26
# Turn: 27
# Turn: 28
# Turn: 29

# %%
sim.save('with_pipe_1')
# Out:
# /home/rsimpson/MPhys Project/Code/Accelerator Simulation/refined_2/scripts/simulation_apertures.py:159: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->Index(['W_matrix'], dtype='str')]
#
#   df_twiss.to_hdf(f'data/{filename}.h5',
# File saved at data/with_pipe_1

# %%
[print(i) for i in sim.line.element_names]
# Out:
# spacecharge_0
# synchrotron$start_aper
# synchrotron$start
# sp0_datum_aper
# sp0_datum
# sp0_dipfr8_0_aper
# sp0_dipfr8_0
# sp0_dipfr8_1_aper
# sp0_dipfr8_1
# sp0_dipfr9_0_aper
# sp0_dipfr9_0
# sp0_dipfr9_1_aper
# sp0_dipfr9_1
# sp0_dipfr10_aper
# sp0_dipfr10
# sp0_d0_00_aper
# sp0_d0_00
# sp0_d0_01_a_aper
# sp0_d0_01_a
# sp0_r0hd1_aper
# sp0_r0hd1
# sp0_d0_01_b_aper
# sp0_d0_01_b
# sp0_d0_02_aper
# sp0_d0_02
# sp0_d0_03_a_aper
# sp0_d0_03_a
# sp0_r0hm1_aper
# sp0_r0hm1
# sp0_d0_03_b_aper
# sp0_d0_03_b
# sp0_d0_04_aper
# sp0_d0_04
# sp0_d0_05_aper
# sp0_d0_05
# sp0_d0_06_aper
# sp0_d0_06
# sp0_d0_07_aper
# sp0_d0_07
# sp0_d0_08_aper
# sp0_d0_08
# sp0_d0_09_aper
# sp0_d0_09
# sp0_d0_10_aper
# sp0_d0_10
# sp0_d0_11_aper
# sp0_d0_11
# sp0_d0_12_aper
# sp0_d0_12..0
# spacecharge_1
# sp0_d0_12..1
# sp0_d0_13_aper
# sp0_d0_13
# sp0_d0_14_aper
# sp0_d0_14
# sp0_d0_15_aper
# sp0_d0_15
# sp0_d0_16_aper
# sp0_d0_16
# sp0_d0_17_aper
# sp0_d0_17
# sp0_d0_18_a_aper
# sp0_d0_18_a
# ...

# %%
[print(i) for i in sim.line.element_names if ('aper' in i) or ('charge' in i)]
# Out:
# spacecharge_0
# synchrotron$start_aper
# sp0_datum_aper
# sp0_dipfr8_0_aper
# sp0_dipfr8_1_aper
# sp0_dipfr9_0_aper
# sp0_dipfr9_1_aper
# sp0_dipfr10_aper
# sp0_d0_00_aper
# sp0_d0_01_a_aper
# sp0_r0hd1_aper
# sp0_d0_01_b_aper
# sp0_d0_02_aper
# sp0_d0_03_a_aper
# sp0_r0hm1_aper
# sp0_d0_03_b_aper
# sp0_d0_04_aper
# sp0_d0_05_aper
# sp0_d0_06_aper
# sp0_d0_07_aper
# sp0_d0_08_aper
# sp0_d0_09_aper
# sp0_d0_10_aper
# sp0_d0_11_aper
# sp0_d0_12_aper
# spacecharge_1
# sp0_d0_13_aper
# sp0_d0_14_aper
# sp0_d0_15_aper
# sp0_d0_16_aper
# sp0_d0_17_aper
# sp0_d0_18_a_aper
# sp0_r0vm1_aper
# sp0_d0_18_b_aper
# sp0_d0_19_aper
# sp0_d0_20_a_aper
# sp0_r0vd1_aper
# sp0_d0_20_b_aper
# sp0_d0_21_aper
# sp0_d0_22_aper
# sp0_d0_23_aper
# sp0_d0_24_aper
# sp0_d0_25_aper
# sp0_qdfr1_aper
# sp0_qdfr2_aper
# sp0_qdfr3_aper
# sp0_qdfr4_aper
# sp0_qd_0_aper
# sp0_qd_1_aper
# sp0_qd_1_aper..0
# sp0_qd_1_aper..1
# spacecharge_2
# sp0_qd_1_aper..2
# sp0_qd_1_aper..3
# sp0_qd_2_aper
# sp0_qd_3_aper
# ...

# %%
for i in range(len(sim.line.element_names)):
    if 'aper' in sim.line.element_names[i]:
        print(sim.line.elements[i].copy())
# Out:
# LimitRect(min_x=-0.088, max_x=0.088, min_y=-0.0571, max_y=0.0571, shift_x=0, shift_y=0, shift_s=0, rot_s_rad=0, rot_x_rad=0, rot_y_rad=0, rot_s_rad_no_frame=0, rot_shift_anchor=0)
# LimitRect(min_x=-0.088, max_x=0.088, min_y=-0.0571, max_y=0.0571, shift_x=0, shift_y=0, shift_s=0, rot_s_rad=0, rot_x_rad=0, rot_y_rad=0, rot_s_rad_no_frame=0, rot_shift_anchor=0)
# LimitRect(min_x=-0.0877, max_x=0.0877, min_y=-0.0577, max_y=0.0577, shift_x=0, shift_y=0, shift_s=0, rot_s_rad=0, rot_x_rad=0, rot_y_rad=0, rot_s_rad_no_frame=0, rot_shift_anchor=0)
# LimitRect(min_x=-0.0872, max_x=0.0872, min_y=-0.0587, max_y=0.0587, shift_x=0, shift_y=0, shift_s=0, rot_s_rad=0, rot_x_rad=0, rot_y_rad=0, rot_s_rad_no_frame=0, rot_shift_anchor=0)
# LimitRect(min_x=-0.0867, max_x=0.0867, min_y=-0.0597, max_y=0.0597, shift_x=0, shift_y=0, shift_s=0, rot_s_rad=0, rot_x_rad=0, rot_y_rad=0, rot_s_rad_no_frame=0, rot_shift_anchor=0)
# ...

# %%
print(sim.line.elements[1].max_x)
# Out:
# 0.087959014

# %%
x = []
for i in range(len(sim.line.element_names)):
    if '_aper' in sim.line.element_names[i]:
        #print(sim.line.elements[i])
        try:
            x.append(sim.line.elements[i].max_x)
        except:
            pass
        
import matplotlib.pyplot as plt
plt.plot(x)
