# %%
from scripts.analysis import Analysis
# Out:
# PyHEADTAIL v1.16.5

# %%
analysis = Analysis('sc_fake_9')
# Out:
# /home/rsimpson/anaconda3/envs/Xtrack/lib/python3.13/site-packages/tables/attributeset.py:322: DataTypeWarning: Unsupported type for attribute 'thick' in node '/'. Offending HDF5 class: 8
#   value = self._g_getattr(self._v_node, name)

# %%
analysis.tune_histogram(xl=1, yl=1)
# Out:
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: title={'center': 'Tune Footprint\nBare Tune: (4.336, 3.830)'}, xlabel='$Q_x$', ylabel='$Q_y$'>)

# %%
import matplotlib.pyplot as plt

for particle in (analysis.x_tbt):
    plt.plot(particle)

plt.show()
