# %%
from scripts.simulation_my_sc import Simulation

# %%
sim = Simulation(n_macro_particles=int(1e4), threads=10)
# Out:
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.

# %%
sim.add_space_charge(beam_intensity=5e11, n_interactions=100)
# Out:
# ...
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]

# %%
sim.run(30)
# Out:
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Turn: 0
# Turn: 1
# Turn: 2
# Turn: 3
# Turn: 4
# Turn: 5
# Turn: 6
# Turn: 7
# Turn: 8
# Turn: 9
# Turn: 10
# Turn: 11
# Turn: 12
# Turn: 13
# Turn: 14
# Turn: 15
# Turn: 16
# Turn: 17
# Turn: 18
# Turn: 19
# Turn: 20
# Turn: 21
# Turn: 22
# Turn: 23
# Turn: 24
# Turn: 25
# Turn: 26
# Turn: 27
# Turn: 28
# Turn: 29

# %%
sim.save('my_sc_4')
# Out:
# /home/rsimpson/MPhys Project/Code/Accelerator Simulation/refined_2/scripts/simulation_my_sc.py:132: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->Index(['W_matrix'], dtype='str')]
#
#   df_twiss.to_hdf(f'data/{filename}.h5',
# File saved at data/my_sc_4

# %%
for i in range(len(sim.line.element_names)):
    if 'aper' in sim.line.element_names[i]:
        print(sim.line.elements[i])
# Out:
# View of LimitRect(min_x=-0.088, max_x=0.088, min_y=-0.0571, max_y=0.0571, shift_x=0, shift_y=0, shift_s=0, rot_s_rad=0, rot_x_rad=0, rot_y_rad=0, rot_s_rad_no_frame=0, rot_shift_anchor=0)
# View of LimitRect(min_x=-0.088, max_x=0.088, min_y=-0.0571, max_y=0.0571, shift_x=0, shift_y=0, shift_s=0, rot_s_rad=0, rot_x_rad=0, rot_y_rad=0, rot_s_rad_no_frame=0, rot_shift_anchor=0)
# View of LimitRect(min_x=-0.0877, max_x=0.0877, min_y=-0.0577, max_y=0.0577, shift_x=0, shift_y=0, shift_s=0, rot_s_rad=0, rot_x_rad=0, rot_y_rad=0, rot_s_rad_no_frame=0, rot_shift_anchor=0)
# View of LimitRect(min_x=-0.0872, max_x=0.0872, min_y=-0.0587, max_y=0.0587, shift_x=0, shift_y=0, shift_s=0, rot_s_rad=0, rot_x_rad=0, rot_y_rad=0, rot_s_rad_no_frame=0, rot_shift_anchor=0)
# View of LimitRect(min_x=-0.0867, max_x=0.0867, min_y=-0.0597, max_y=0.0597, shift_x=0, shift_y=0, shift_s=0, rot_s_rad=0, rot_x_rad=0, rot_y_rad=0, rot_s_rad_no_frame=0, rot_shift_anchor=0)
# ...
