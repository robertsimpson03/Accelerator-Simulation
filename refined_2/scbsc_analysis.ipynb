# %%
from scripts.analysis_scbsc import Analysis
# Out:
# PyHEADTAIL v1.16.5

# %%
analysis = Analysis('with_pipe_1')

# %%
analysis.tune_histogram()
# Out:
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: title={'center': 'Tune Footprint\nBare Tune: (4.33595, 3.83026)'}, xlabel='$Q_x$', ylabel='$Q_y$'>)

# %%
analysis = Analysis('my_sc_4')

# %%
analysis.tune_histogram()
# Out:
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: title={'center': 'Tune Footprint\nBare Tune: (4.33595, 3.83026)'}, xlabel='$Q_x$', ylabel='$Q_y$'>)
