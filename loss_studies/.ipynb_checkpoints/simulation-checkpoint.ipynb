# %%
import sys
from pathlib import Path

parent_folder = Path.cwd().parent
if str(parent_folder) not in sys.path:
    sys.path.append(str(parent_folder))
    
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
from simulation import Simulation

# %% [markdown]
# # Default Bare Lattice

# %%
beta_gamma = 0.3934 
emittance = 60e-6 * beta_gamma
sim = Simulation(threads=10, folder=Path('../Lattice_Files/02_Aperture_Lattice/'))
sim.build_particles(n_particles=1000, 
                    nemitt_x_0=emittance, 
                    nemitt_y_0=emittance)
sim.set_up(n_turns = 100, n_monitors = 10)
sim.run()
sim.save('data/default_bare')
# Out:
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# File saved at data/default_bare

# %% [markdown]
# # Bare lattice Sweep Emmitance

# %%
emittance = 300e-6
beta_gamma = 0.3934 

ratio_list = [1, 1/2, 1/4, 1/6, 1/8, 1/10]

for ratio in ratio_list:
    if ratio!=1:
        sim = Simulation(
            threads=10,
            folder=Path('../Lattice_Files/02_Aperture_Lattice/'))
        sim.build_particles(n_particles=1000, 
                            nemitt_x_0=emittance*ratio, 
                            nemitt_y_0=emittance*ratio)
        sim.set_up(n_turns = 10, n_monitors = 10)
        sim.run()
        sim.save(f'data/sweep_emittance_bare_ratio/ratio_{ratio}')
    
    sim = Simulation(
        threads=10,
        folder=Path('../Lattice_Files/02_Aperture_Lattice/'))
    sim.build_particles(n_particles=1000, 
                        nemitt_x_0=beta_gamma*emittance*ratio, 
                        nemitt_y_0=beta_gamma*emittance*ratio)
    sim.set_up(n_turns = 10, n_monitors = 10)
    sim.run()
    sim.save(f'data/sweep_emittance_bare_ratio/ratio_{ratio}_geom')
# Out:
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# File saved at data/sweep_emittance_bare_ratio/ratio_1_geom
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# File saved at data/sweep_emittance_bare_ratio/ratio_0.5
# ...

# %% [markdown]
# # Get bare admittance

# %%
import pandas as pd
def calculate_admittance(line):
    tw = line.twiss(method='4d', freeze_longitudinal=True)
    names = []
    w_x_limits = []
    w_y_limits = []
    s_positions = []

    for name in line.element_names:
        el = line[name]
        if hasattr(el, 'min_x') and hasattr(el, 'max_x'):
            a_x = (el.max_x - el.min_x) / 2
            a_y = (el.max_y - el.min_y) / 2
            
            idx = np.where(tw.name == name)[0][0]
            betx = tw.betx[idx]
            bety = tw.bety[idx]
            
            x_co = abs(tw.x[idx])
            y_co = abs(tw.y[idx])
            
            w_x_limits.append((a_x-x_co)**2 / betx)
            w_y_limits.append((a_y-y_co)**2 / bety)
            s_positions.append(tw.s[idx])
            names.append(name)

    adm_x = np.min(w_x_limits)
    adm_y = np.min(w_y_limits)
    bn_x_name = names[np.argmin(w_x_limits)]
    bn_y_name = names[np.argmin(w_y_limits)]

    print(f"--- Lattice Admittance Results ---")
    print(f"Horizontal Admittance: {adm_x*1e6:.2f} pi mm mrad (Bottleneck: {bn_x_name})")
    print(f"Vertical Admittance:   {adm_y*1e6:.2f} pi mm mrad (Bottleneck: {bn_y_name})")
    return adm_x, adm_y

admit_x, admit_y = calculate_admittance(sim.line)
# Out:
# --- Lattice Admittance Results ---
# Horizontal Admittance: 719.86 pi mm mrad (Bottleneck: sp2_dip5_3_aper)
# Vertical Admittance:   478.95 pi mm mrad (Bottleneck: sp8_dipfr2_0_aper)

# %% [markdown]
# # Direct SC emittance sweep

# %%
import itertools

nemitt_list = [1e-6, 4e-6, 1e-5]
perms = list(itertools.product(nemitt_list,nemitt_list))

for nemitt_x, nemitt_y in perms:
    sim = Simulation(
        threads=10,
        folder=Path('../Lattice_Files/02_Aperture_Lattice/')
    )
    
    sim.build_particles(n_particles=1000, nemitt_x_0=nemitt_x, nemitt_y_0=nemitt_y)
    sim.set_up(n_turns = 10, n_monitors = 10)
    sim.run(spacecharge=True, beam_intensity=1e10, n_interactions=100, xfields=True)
    sim.save(f'data/sweep_emittance_sc/x:{nemitt_x}_y:{nemitt_y}')
# Out:
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# ...
# Slicing line:   0%|          | 0/3990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# File saved at data/sweep_emittance_sc/x:1e-06_y:1e-06
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# ...
