# %%
from analysis import Analysis

# %%
analysis = Analysis('co_1e-3')

# %%
print(analysis.n_macro_particles)
# Out:
# co

# %%
analysis.tune_histogram()

# %%
analysis.plot_spectrum('x')

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(analysis.y_scbsc[0])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 plt.plot(analysis.twiss.x)
#
# AttributeError: 'Group' object has no attribute 'x'
