# %%
import sys
from pathlib import Path

parent_folder = Path.cwd().parent
if str(parent_folder) not in sys.path:
    sys.path.append(str(parent_folder))
    
import warnings
warnings.filterwarnings('ignore')
import numpy as np

from simulation import Simulation

# %% [markdown]
# ## Direct SC

# %%
sim = Simulation(threads=10, folder=Path('../Lattice_Files/02_Aperture_Lattice_mod/'))
beta_gamma = sim.line.particle_ref.beta0*sim.line.particle_ref.gamma0
sim.build_particles(n_particles=1000, nemitt_x_0=beta_gamma*60e-6, nemitt_y_0=beta_gamma*60e-6)
sim.set_up(n_turns = 100, n_monitors = 100)
sim.add_spacecharge(beam_intensity=1e13, n_interactions=100)
sim.run()
sim.save('data/basic/dir_sc')
# Out:
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# File saved at data/basic/dir_sc

# %% [markdown]
# ## Indirect SC

# %%
sim = Simulation(threads=10, folder=Path('../Lattice_Files/02_Aperture_Lattice_mod/'))
beta_gamma = sim.line.particle_ref.beta0*sim.line.particle_ref.gamma0
sim.build_particles(n_particles=1000, nemitt_x_0=beta_gamma*60e-6, nemitt_y_0=beta_gamma*60e-6)
sim.set_up(n_turns = 100, n_monitors = 100)
sim.add_spacecharge(beam_intensity=1e13, n_interactions=100, indirect_spacecharge=True)
sim.run()
sim.save('data/basic/ind_sc')
# Out:
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# File saved at data/basic/ind_sc

# %% [markdown]
# # Single particle tracking - move to a new notebook

# %%
offsets = [0, 0.0001, 0.0004, 0.001, 0.004, 0.01, 0.04, 0.1]

for dx in offsets:
    #sim = Simulation(threads=0, folder=Path('../Lattice_Files/02_Aperture_Lattice_mod/'))
    #beta_gamma = sim.line.particle_ref.beta0*sim.line.particle_ref.gamma0
    #sim.build_particles(co=True, offset_x=dx)
    #sim.set_up(n_turns = 100, n_monitors = 100)
    #sim.add_spacecharge(beam_intensity=1e13, n_interactions=100, 
    #                    nemitt_x=beta_gamma*60e-6, nemitt_y=beta_gamma*60e-6)
    #sim.run()
    #sim.save(f'data/sweep_offset/dir_{dx}')

    sim = Simulation(threads=0, folder=Path('../Lattice_Files/02_Aperture_Lattice_mod/'))
    beta_gamma = sim.line.particle_ref.beta0*sim.line.particle_ref.gamma0
    sim.build_particles(co=True, offset_x=dx)
    sim.set_up(n_turns = 100, n_monitors = 100)
    sim.add_spacecharge(beam_intensity=1e13, n_interactions=100, indirect_spacecharge=True, 
                        nemitt_x=beta_gamma*60e-6, nemitt_y=beta_gamma*60e-6,
                        pipe_enlargement=10)
    sim.run()
    sim.save(f'data/sweep_offset/ultrawide_{dx}')
# Out:
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# File saved at data/sweep_offset/ultrawide_0
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Intensity sweep

# %%
int_list = [1e12, 2e12, 5e12, 1e13, 2e13, 5e13, 1e14]

for inte in int_list:
    sim = Simulation(threads=0, folder=Path('../Lattice_Files/02_Aperture_Lattice_mod/'))
    beta_gamma = sim.line.particle_ref.beta0*sim.line.particle_ref.gamma0
    sim.build_particles(n_particles=1000, nemitt_x_0=beta_gamma*60e-6, 
                        nemitt_y_0=beta_gamma*60e-6)
    sim.set_up(n_turns = 100, n_monitors = 100)
    sim.add_spacecharge(beam_intensity=inte, n_interactions=100)
    sim.run()
    sim.save(f'data/sweep_intensity/dir_{inte}')

    sim = Simulation(threads=0, folder=Path('../Lattice_Files/02_Aperture_Lattice_mod/'))
    sim.build_particles(n_particles=1000, nemitt_x_0=beta_gamma*60e-6, 
                        nemitt_y_0=beta_gamma*60e-6)
    sim.set_up(n_turns = 100, n_monitors = 100)
    sim.add_spacecharge(beam_intensity=inte, n_interactions=100, indirect_spacecharge=True)
    sim.run()
    sim.save(f'data/sweep_intensity/ind_{inte}')
# Out:
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# File saved at data/sweep_intensity/dir_1000000000000.0
# Converting sequence "synchrotron":   0%|          | 0/1990 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/3980 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Slicing line:   0%|          | 0/4570 [00:00<?, ?it/s]
# ...
