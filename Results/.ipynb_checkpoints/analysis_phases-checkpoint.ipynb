# %% [markdown]
# # Analysis_phases

# %%
import sys
from pathlib import Path

parent_folder = Path.cwd().parent
if str(parent_folder) not in sys.path:
    sys.path.append(str(parent_folder))
    
import warnings
warnings.filterwarnings('ignore')

import scienceplots

import numpy as np
import matplotlib.pyplot as plt

plt.style.use('science')

from analysis import Analysis
import nafflib
# Out:
# PyHEADTAIL v1.16.5

# %%
a = Analysis('data/phases/dir_sc')
Qx_a = a.get_tunes(a.x[a.survivor_mask], a.px[a.survivor_mask], 'x')
Qy_a = a.get_tunes(a.y[a.survivor_mask], a.py[a.survivor_mask], 'y')

# %%
plt.hist2d(Qx_a, Qy_a, bins=100, cmap='Blues', range=[(4.2,4.5), (3.5,3.8)])
plt.scatter(a.qx, a.qy, marker='*', s=100, c='r', label='Bare Tune')

# %%
for i in range(50):
    plt.scatter(a.y.T[i], a.py.T[i], marker='.', alpha=0.2)
